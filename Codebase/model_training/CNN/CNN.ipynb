# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

import sys
sys.path.append('/Users/oabas/Documents/GitHub/Exercise-Pose-Detection/Codebase/model_training')
from data import BodyPart

from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score

import tensorflow as tf
import tensorflowjs as tfjs
from tensorflow import keras

# %%
tfjs_model_dir = 'model'

# %%
def load_csv(csv_path):
    df = pd.read_csv(csv_path)
    df.drop(['filename'],axis=1, inplace=True)
    classes = df.pop('class_name').unique()
    y = df.pop('class_no')

    X = df.astype('float64')
    y = keras.utils.to_categorical(y)
    
    return X, y, classes


def get_center_point(landmarks, left_bodypart, right_bodypart):
    left = tf.gather(landmarks, left_bodypart.value, axis=1)
    right = tf.gather(landmarks, right_bodypart.value, axis=1)
    center = left * 0.5 + right * 0.5
    return center

# %%
def get_pose_size(landmarks, torso_size_multiplier=2.5):
  
    hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                 BodyPart.RIGHT_HIP)

    shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER,
                                      BodyPart.RIGHT_SHOULDER)

    # Torso size as the minimum body size
    torso_size = tf.linalg.norm(shoulders_center - hips_center)
    # Pose center
    pose_center_new = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                     BodyPart.RIGHT_HIP)
    pose_center_new = tf.expand_dims(pose_center_new, axis=1)
    # Broadcast the pose center to the same size as the landmark vector to
    # perform substraction
    pose_center_new = tf.broadcast_to(pose_center_new,
                                    [tf.size(landmarks) // (17*2), 17, 2])

    # Dist to pose center
    d = tf.gather(landmarks - pose_center_new, 0, axis=0,
                name="dist_to_pose_center")
    # Max dist to pose center
    max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

    # Normalize scale
    pose_size = tf.maximum(torso_size * torso_size_multiplier, max_dist)
    return pose_size

# %%
def normalize_pose_landmarks(landmarks):
    """Normalizes the landmarks translation by moving the pose center to (0,0) and
    scaling it to a constant pose size.
  """
  # Move landmarks so that the pose center becomes (0,0)
    pose_center = get_center_point(landmarks, BodyPart.LEFT_HIP, 
                                 BodyPart.RIGHT_HIP)

    pose_center = tf.expand_dims(pose_center, axis=1)
    # Broadcast the pose center to the same size as the landmark vector to perform
    # substraction
    pose_center = tf.broadcast_to(pose_center, 
                                [tf.size(landmarks) // (17*2), 17, 2])
    landmarks = landmarks - pose_center

    # Scale the landmarks to a constant pose size
    pose_size = get_pose_size(landmarks)
    landmarks /= pose_size
    return landmarks

# %%
def landmarks_to_embedding(landmarks_and_scores):
    """Converts the input landmarks into a pose embedding."""
    # Reshape the flat input into a matrix with shape=(17, 3)
    reshaped_inputs = keras.layers.Reshape((17, 3))(landmarks_and_scores)

    # Normalize landmarks 2D
    landmarks = normalize_pose_landmarks(reshaped_inputs[:, :, :2])
    # Flatten the normalized landmark coordinates into a vector
    embedding = keras.layers.Flatten()(landmarks)
    return embedding

# %%
def preprocess_data(X_train):
    processed_X_train = []
    for i in range(X_train.shape[0]):
        embedding = landmarks_to_embedding(tf.reshape(tf.convert_to_tensor(X_train.iloc[i]), (1, 51)))
        processed_X_train.append(tf.reshape(embedding, (34)))
    return tf.convert_to_tensor(processed_X_train)

# %%
X, y, class_names = load_csv('../../../Data/model_data/train_data.csv')
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15)
X_test, y_test, _ = load_csv('../../../Data/model_data/test_data.csv')
num_classes = len(class_names)

# %%
processed_X_train = preprocess_data(X_train)
processed_X_val =  preprocess_data(X_val)
processed_X_test = preprocess_data(X_test)
# Out:
# Metal device set to: Apple M2
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB

# %%
print("Shape of processed_X_train:", processed_X_train.shape)
print("Shape of processed_X_val:", processed_X_val.shape)
print("Shape of processed_X_test:", processed_X_test.shape)
# Out:
# Shape of processed_X_train: (5357, 34)
# Shape of processed_X_val: (946, 34)
# Shape of processed_X_test: (1303, 34)

# %%
print("Shape of y_train:", y_train.shape)
print("Shape of y_val:", y_val.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of y_train: (5357, 13)
# Shape of y_val: (946, 13)
# Shape of y_test: (1303, 13)

# %%
inputs = keras.Input(shape=(34, 1))
x = keras.layers.Conv1D(32, 3, activation='relu')(inputs)
x = keras.layers.MaxPool1D()(x)

x = keras.layers.Conv1D(64, 3, activation='relu')(x)
x = keras.layers.MaxPool1D()(x)

x = keras.layers.Flatten()(x)

x = keras.layers.Dense(128, activation='relu')(x)
outputs = keras.layers.Dense(num_classes, activation='softmax')(x)

# %%
model_cnn = keras.Model(inputs, outputs)

model_cnn.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Add a checkpoint callback to store the checkpoint that has the highest validation accuracy.
checkpoint_path = "CNN_tf.h5"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path,
                                             monitor='val_accuracy',
                                             verbose=1,
                                             save_best_only=True,
                                             mode='max')
earlystopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', 
                                              patience=20)

# %%
# Start training
print('--------------TRAINING CNN MODEL----------------')
history_cnn = model_cnn.fit(processed_X_train, y_train,
                            epochs=150,
                            batch_size=16,
                            validation_data=(processed_X_val, y_val),
                            callbacks=[checkpoint, earlystopping])

print('-----------------EVALUATION----------------')
loss, accuracy = model_cnn.evaluate(processed_X_test, y_test)
print('LOSS: ', loss)
print("ACCURACY: ", accuracy)
# Out:
# --------------TRAINING CNN MODEL----------------
# Epoch 1/150
# 335/335 [==============================] - ETA: 0s - loss: 1.3325 - accuracy: 0.5658
# Epoch 1: val_accuracy improved from -inf to 0.74313, saving model to CNN_tf.h5
# 335/335 [==============================] - 12s 22ms/step - loss: 1.3325 - accuracy: 0.5658 - val_loss: 0.7557 - val_accuracy: 0.7431
# Epoch 2/150
#   5/335 [..............................] - ETA: 5s - loss: 0.8914 - accuracy: 0.6500
# /Users/oabas/miniconda3/lib/python3.9/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 335/335 [==============================] - ETA: 0s - loss: 0.6295 - accuracy: 0.7889
# Epoch 2: val_accuracy improved from 0.74313 to 0.84778, saving model to CNN_tf.h5
# 335/335 [==============================] - 6s 17ms/step - loss: 0.6295 - accuracy: 0.7889 - val_loss: 0.4596 - val_accuracy: 0.8478
# Epoch 3/150
# 335/335 [==============================] - ETA: 0s - loss: 0.3825 - accuracy: 0.8794
# Epoch 3: val_accuracy improved from 0.84778 to 0.88901, saving model to CNN_tf.h5
# 335/335 [==============================] - 6s 17ms/step - loss: 0.3825 - accuracy: 0.8794 - val_loss: 0.3349 - val_accuracy: 0.8890
# Epoch 4/150
# 332/335 [============================>.] - ETA: 0s - loss: 0.2691 - accuracy: 0.9162
# Epoch 4: val_accuracy improved from 0.88901 to 0.91860, saving model to CNN_tf.h5
# 335/335 [==============================] - 5s 16ms/step - loss: 0.2690 - accuracy: 0.9164 - val_loss: 0.2265 - val_accuracy: 0.9186
# Epoch 5/150
# 334/335 [============================>.] - ETA: 0s - loss: 0.2101 - accuracy: 0.9308
# Epoch 5: val_accuracy improved from 0.91860 to 0.92178, saving model to CNN_tf.h5
# 335/335 [==============================] - 6s 16ms/step - loss: 0.2102 - accuracy: 0.9306 - val_loss: 0.2007 - val_accuracy: 0.9218
# Epoch 6/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.1774 - accuracy: 0.9399
# Epoch 6: val_accuracy improved from 0.92178 to 0.94292, saving model to CNN_tf.h5
# 335/335 [==============================] - 7s 20ms/step - loss: 0.1771 - accuracy: 0.9401 - val_loss: 0.1703 - val_accuracy: 0.9429
# Epoch 7/150
# 332/335 [============================>.] - ETA: 0s - loss: 0.1539 - accuracy: 0.9475
# Epoch 7: val_accuracy improved from 0.94292 to 0.94926, saving model to CNN_tf.h5
# 335/335 [==============================] - 6s 19ms/step - loss: 0.1531 - accuracy: 0.9477 - val_loss: 0.1403 - val_accuracy: 0.9493
# Epoch 8/150
# 335/335 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9580
# Epoch 8: val_accuracy did not improve from 0.94926
# 335/335 [==============================] - 6s 17ms/step - loss: 0.1313 - accuracy: 0.9580 - val_loss: 0.1828 - val_accuracy: 0.9323
# Epoch 9/150
# 335/335 [==============================] - ETA: 0s - loss: 0.1201 - accuracy: 0.9599
# Epoch 9: val_accuracy improved from 0.94926 to 0.95666, saving model to CNN_tf.h5
# 335/335 [==============================] - 5s 16ms/step - loss: 0.1201 - accuracy: 0.9599 - val_loss: 0.1234 - val_accuracy: 0.9567
# Epoch 10/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.1153 - accuracy: 0.9613
# Epoch 10: val_accuracy improved from 0.95666 to 0.96829, saving model to CNN_tf.h5
# 335/335 [==============================] - 6s 19ms/step - loss: 0.1159 - accuracy: 0.9610 - val_loss: 0.0904 - val_accuracy: 0.9683
# Epoch 11/150
# 335/335 [==============================] - ETA: 0s - loss: 0.1020 - accuracy: 0.9664
# Epoch 11: val_accuracy did not improve from 0.96829
# 335/335 [==============================] - 6s 18ms/step - loss: 0.1020 - accuracy: 0.9664 - val_loss: 0.0914 - val_accuracy: 0.9662
# Epoch 12/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9681
# Epoch 12: val_accuracy did not improve from 0.96829
# 335/335 [==============================] - 5s 16ms/step - loss: 0.0938 - accuracy: 0.9681 - val_loss: 0.1026 - val_accuracy: 0.9598
# Epoch 13/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0908 - accuracy: 0.9703
# Epoch 13: val_accuracy improved from 0.96829 to 0.97146, saving model to CNN_tf.h5
# 335/335 [==============================] - 5s 16ms/step - loss: 0.0908 - accuracy: 0.9701 - val_loss: 0.0846 - val_accuracy: 0.9715
# Epoch 14/150
# 332/335 [============================>.] - ETA: 0s - loss: 0.0775 - accuracy: 0.9744
# Epoch 14: val_accuracy improved from 0.97146 to 0.97674, saving model to CNN_tf.h5
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0773 - accuracy: 0.9744 - val_loss: 0.0716 - val_accuracy: 0.9767
# Epoch 15/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0743 - accuracy: 0.9770
# Epoch 15: val_accuracy improved from 0.97674 to 0.97992, saving model to CNN_tf.h5
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0743 - accuracy: 0.9770 - val_loss: 0.0704 - val_accuracy: 0.9799
# Epoch 16/150
# 334/335 [============================>.] - ETA: 0s - loss: 0.0727 - accuracy: 0.9770
# Epoch 16: val_accuracy did not improve from 0.97992
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0727 - accuracy: 0.9770 - val_loss: 0.0892 - val_accuracy: 0.9693
# Epoch 17/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0726 - accuracy: 0.9769
# Epoch 17: val_accuracy did not improve from 0.97992
# 335/335 [==============================] - 6s 17ms/step - loss: 0.0726 - accuracy: 0.9769 - val_loss: 0.0726 - val_accuracy: 0.9778
# Epoch 18/150
# 331/335 [============================>.] - ETA: 0s - loss: 0.0658 - accuracy: 0.9783
# Epoch 18: val_accuracy did not improve from 0.97992
# 335/335 [==============================] - 5s 16ms/step - loss: 0.0660 - accuracy: 0.9783 - val_loss: 0.0684 - val_accuracy: 0.9789
# Epoch 19/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0650 - accuracy: 0.9795
# Epoch 19: val_accuracy did not improve from 0.97992
# 335/335 [==============================] - 5s 16ms/step - loss: 0.0650 - accuracy: 0.9795 - val_loss: 0.0807 - val_accuracy: 0.9693
# Epoch 20/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0625 - accuracy: 0.9793
# Epoch 20: val_accuracy did not improve from 0.97992
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0625 - accuracy: 0.9793 - val_loss: 0.0779 - val_accuracy: 0.9725
# Epoch 21/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0552 - accuracy: 0.9809
# Epoch 21: val_accuracy improved from 0.97992 to 0.98097, saving model to CNN_tf.h5
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0550 - accuracy: 0.9810 - val_loss: 0.0505 - val_accuracy: 0.9810
# Epoch 22/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0536 - accuracy: 0.9824
# Epoch 22: val_accuracy improved from 0.98097 to 0.98414, saving model to CNN_tf.h5
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0537 - accuracy: 0.9823 - val_loss: 0.0559 - val_accuracy: 0.9841
# Epoch 23/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0507 - accuracy: 0.9844
# Epoch 23: val_accuracy did not improve from 0.98414
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0509 - accuracy: 0.9843 - val_loss: 0.0440 - val_accuracy: 0.9831
# Epoch 24/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0439 - accuracy: 0.9869
# Epoch 24: val_accuracy improved from 0.98414 to 0.98626, saving model to CNN_tf.h5
# 335/335 [==============================] - 5s 16ms/step - loss: 0.0438 - accuracy: 0.9869 - val_loss: 0.0442 - val_accuracy: 0.9863
# Epoch 25/150
# 334/335 [============================>.] - ETA: 0s - loss: 0.0502 - accuracy: 0.9847
# Epoch 25: val_accuracy did not improve from 0.98626
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0501 - accuracy: 0.9847 - val_loss: 0.0669 - val_accuracy: 0.9789
# Epoch 26/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0513 - accuracy: 0.9830
# Epoch 26: val_accuracy improved from 0.98626 to 0.98731, saving model to CNN_tf.h5
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0513 - accuracy: 0.9830 - val_loss: 0.0532 - val_accuracy: 0.9873
# Epoch 27/150
# 334/335 [============================>.] - ETA: 0s - loss: 0.0386 - accuracy: 0.9863
# Epoch 27: val_accuracy did not improve from 0.98731
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0387 - accuracy: 0.9862 - val_loss: 0.0502 - val_accuracy: 0.9873
# Epoch 28/150
# 332/335 [============================>.] - ETA: 0s - loss: 0.0381 - accuracy: 0.9880
# Epoch 28: val_accuracy improved from 0.98731 to 0.98837, saving model to CNN_tf.h5
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0381 - accuracy: 0.9879 - val_loss: 0.0381 - val_accuracy: 0.9884
# Epoch 29/150
# 334/335 [============================>.] - ETA: 0s - loss: 0.0418 - accuracy: 0.9860
# Epoch 29: val_accuracy did not improve from 0.98837
# 335/335 [==============================] - 6s 17ms/step - loss: 0.0417 - accuracy: 0.9860 - val_loss: 0.0428 - val_accuracy: 0.9873
# Epoch 30/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0370 - accuracy: 0.9867
# Epoch 30: val_accuracy did not improve from 0.98837
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0372 - accuracy: 0.9866 - val_loss: 0.0623 - val_accuracy: 0.9820
# Epoch 31/150
# 332/335 [============================>.] - ETA: 0s - loss: 0.0414 - accuracy: 0.9872
# Epoch 31: val_accuracy did not improve from 0.98837
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0418 - accuracy: 0.9867 - val_loss: 0.0502 - val_accuracy: 0.9884
# Epoch 32/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0384 - accuracy: 0.9877
# Epoch 32: val_accuracy improved from 0.98837 to 0.98943, saving model to CNN_tf.h5
# 335/335 [==============================] - 6s 17ms/step - loss: 0.0384 - accuracy: 0.9877 - val_loss: 0.0368 - val_accuracy: 0.9894
# Epoch 33/150
# 331/335 [============================>.] - ETA: 0s - loss: 0.0304 - accuracy: 0.9902
# Epoch 33: val_accuracy did not improve from 0.98943
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0302 - accuracy: 0.9903 - val_loss: 0.0428 - val_accuracy: 0.9873
# Epoch 34/150
# 331/335 [============================>.] - ETA: 0s - loss: 0.0327 - accuracy: 0.9877
# Epoch 34: val_accuracy improved from 0.98943 to 0.99154, saving model to CNN_tf.h5
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0325 - accuracy: 0.9879 - val_loss: 0.0358 - val_accuracy: 0.9915
# Epoch 35/150
# 332/335 [============================>.] - ETA: 0s - loss: 0.0301 - accuracy: 0.9908
# Epoch 35: val_accuracy did not improve from 0.99154
# 335/335 [==============================] - 4s 13ms/step - loss: 0.0299 - accuracy: 0.9909 - val_loss: 0.0331 - val_accuracy: 0.9894
# Epoch 36/150
# 331/335 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 0.9881
# Epoch 36: val_accuracy did not improve from 0.99154
# 335/335 [==============================] - 4s 13ms/step - loss: 0.0309 - accuracy: 0.9881 - val_loss: 0.0478 - val_accuracy: 0.9841
# Epoch 37/150
# 334/335 [============================>.] - ETA: 0s - loss: 0.0369 - accuracy: 0.9882
# Epoch 37: val_accuracy did not improve from 0.99154
# 335/335 [==============================] - 5s 13ms/step - loss: 0.0371 - accuracy: 0.9881 - val_loss: 0.0371 - val_accuracy: 0.9905
# Epoch 38/150
# 334/335 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 0.9914
# Epoch 38: val_accuracy did not improve from 0.99154
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0245 - accuracy: 0.9914 - val_loss: 0.0330 - val_accuracy: 0.9905
# Epoch 39/150
# 332/335 [============================>.] - ETA: 0s - loss: 0.0253 - accuracy: 0.9923
# Epoch 39: val_accuracy did not improve from 0.99154
# 335/335 [==============================] - 4s 13ms/step - loss: 0.0253 - accuracy: 0.9922 - val_loss: 0.0389 - val_accuracy: 0.9873
# Epoch 40/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9931
# Epoch 40: val_accuracy did not improve from 0.99154
# 335/335 [==============================] - 4s 13ms/step - loss: 0.0214 - accuracy: 0.9931 - val_loss: 0.0334 - val_accuracy: 0.9884
# Epoch 41/150
# 334/335 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 0.9931
# Epoch 41: val_accuracy did not improve from 0.99154
# 335/335 [==============================] - 5s 16ms/step - loss: 0.0225 - accuracy: 0.9931 - val_loss: 0.0467 - val_accuracy: 0.9852
# Epoch 42/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9907
# Epoch 42: val_accuracy did not improve from 0.99154
# 335/335 [==============================] - 5s 16ms/step - loss: 0.0297 - accuracy: 0.9907 - val_loss: 0.0335 - val_accuracy: 0.9894
# Epoch 43/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9918
# Epoch 43: val_accuracy did not improve from 0.99154
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0276 - accuracy: 0.9918 - val_loss: 0.0326 - val_accuracy: 0.9905
# Epoch 44/150
# 332/335 [============================>.] - ETA: 0s - loss: 0.0237 - accuracy: 0.9927
# Epoch 44: val_accuracy did not improve from 0.99154
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0237 - accuracy: 0.9927 - val_loss: 0.0559 - val_accuracy: 0.9799
# Epoch 45/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9942
# Epoch 45: val_accuracy did not improve from 0.99154
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0185 - accuracy: 0.9942 - val_loss: 0.0268 - val_accuracy: 0.9915
# Epoch 46/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9935
# Epoch 46: val_accuracy did not improve from 0.99154
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0177 - accuracy: 0.9935 - val_loss: 0.0284 - val_accuracy: 0.9905
# Epoch 47/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0179 - accuracy: 0.9936
# Epoch 47: val_accuracy did not improve from 0.99154
# 335/335 [==============================] - 6s 17ms/step - loss: 0.0178 - accuracy: 0.9937 - val_loss: 0.0277 - val_accuracy: 0.9894
# Epoch 48/150
# 334/335 [============================>.] - ETA: 0s - loss: 0.0165 - accuracy: 0.9938
# Epoch 48: val_accuracy did not improve from 0.99154
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0165 - accuracy: 0.9938 - val_loss: 0.0319 - val_accuracy: 0.9915
# Epoch 49/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0173 - accuracy: 0.9947
# Epoch 49: val_accuracy did not improve from 0.99154
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0175 - accuracy: 0.9946 - val_loss: 0.0315 - val_accuracy: 0.9894
# Epoch 50/150
# 332/335 [============================>.] - ETA: 0s - loss: 0.0148 - accuracy: 0.9944
# Epoch 50: val_accuracy improved from 0.99154 to 0.99260, saving model to CNN_tf.h5
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0147 - accuracy: 0.9944 - val_loss: 0.0369 - val_accuracy: 0.9926
# Epoch 51/150
# 334/335 [============================>.] - ETA: 0s - loss: 0.0167 - accuracy: 0.9949
# Epoch 51: val_accuracy did not improve from 0.99260
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.0248 - val_accuracy: 0.9926
# Epoch 52/150
# 334/335 [============================>.] - ETA: 0s - loss: 0.0161 - accuracy: 0.9940
# Epoch 52: val_accuracy did not improve from 0.99260
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0161 - accuracy: 0.9940 - val_loss: 0.0332 - val_accuracy: 0.9905
# Epoch 53/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0195 - accuracy: 0.9936
# Epoch 53: val_accuracy did not improve from 0.99260
# 335/335 [==============================] - 5s 16ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.0258 - val_accuracy: 0.9905
# Epoch 54/150
# 332/335 [============================>.] - ETA: 0s - loss: 0.0191 - accuracy: 0.9928
# Epoch 54: val_accuracy did not improve from 0.99260
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0194 - accuracy: 0.9927 - val_loss: 0.0289 - val_accuracy: 0.9915
# Epoch 55/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9929
# Epoch 55: val_accuracy did not improve from 0.99260
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0205 - accuracy: 0.9929 - val_loss: 0.0240 - val_accuracy: 0.9915
# Epoch 56/150
# 332/335 [============================>.] - ETA: 0s - loss: 0.0119 - accuracy: 0.9959
# Epoch 56: val_accuracy did not improve from 0.99260
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0118 - accuracy: 0.9959 - val_loss: 0.0223 - val_accuracy: 0.9915
# Epoch 57/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9970
# Epoch 57: val_accuracy did not improve from 0.99260
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.0245 - val_accuracy: 0.9905
# Epoch 58/150
# 334/335 [============================>.] - ETA: 0s - loss: 0.0097 - accuracy: 0.9964
# Epoch 58: val_accuracy did not improve from 0.99260
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.0195 - val_accuracy: 0.9915
# Epoch 59/150
# 334/335 [============================>.] - ETA: 0s - loss: 0.0139 - accuracy: 0.9949
# Epoch 59: val_accuracy did not improve from 0.99260
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0139 - accuracy: 0.9950 - val_loss: 0.0370 - val_accuracy: 0.9863
# Epoch 60/150
# 332/335 [============================>.] - ETA: 0s - loss: 0.0197 - accuracy: 0.9930
# Epoch 60: val_accuracy improved from 0.99260 to 0.99366, saving model to CNN_tf.h5
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0196 - accuracy: 0.9931 - val_loss: 0.0244 - val_accuracy: 0.9937
# Epoch 61/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9959
# Epoch 61: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 0.0365 - val_accuracy: 0.9905
# Epoch 62/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0094 - accuracy: 0.9979
# Epoch 62: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0094 - accuracy: 0.9979 - val_loss: 0.0252 - val_accuracy: 0.9926
# Epoch 63/150
# 331/335 [============================>.] - ETA: 0s - loss: 0.0144 - accuracy: 0.9966
# Epoch 63: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0147 - accuracy: 0.9965 - val_loss: 0.0299 - val_accuracy: 0.9894
# Epoch 64/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9968
# Epoch 64: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0119 - accuracy: 0.9968 - val_loss: 0.0188 - val_accuracy: 0.9926
# Epoch 65/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9965
# Epoch 65: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 16ms/step - loss: 0.0085 - accuracy: 0.9965 - val_loss: 0.0269 - val_accuracy: 0.9905
# Epoch 66/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0079 - accuracy: 0.9976
# Epoch 66: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 16ms/step - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.0147 - val_accuracy: 0.9926
# Epoch 67/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0072 - accuracy: 0.9977
# Epoch 67: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0288 - val_accuracy: 0.9905
# Epoch 68/150
# 332/335 [============================>.] - ETA: 0s - loss: 0.0284 - accuracy: 0.9919
# Epoch 68: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0283 - accuracy: 0.9918 - val_loss: 0.0344 - val_accuracy: 0.9894
# Epoch 69/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9968
# Epoch 69: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.0265 - val_accuracy: 0.9926
# Epoch 70/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0124 - accuracy: 0.9953
# Epoch 70: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0123 - accuracy: 0.9953 - val_loss: 0.0267 - val_accuracy: 0.9905
# Epoch 71/150
# 334/335 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 0.9974
# Epoch 71: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0089 - accuracy: 0.9974 - val_loss: 0.0235 - val_accuracy: 0.9926
# Epoch 72/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 0.9970
# Epoch 72: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0076 - accuracy: 0.9970 - val_loss: 0.0379 - val_accuracy: 0.9894
# Epoch 73/150
# 335/335 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 0.9959
# Epoch 73: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0118 - accuracy: 0.9959 - val_loss: 0.0324 - val_accuracy: 0.9905
# Epoch 74/150
# 334/335 [============================>.] - ETA: 0s - loss: 0.0091 - accuracy: 0.9970
# Epoch 74: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.0238 - val_accuracy: 0.9915
# Epoch 75/150
# 334/335 [============================>.] - ETA: 0s - loss: 0.0066 - accuracy: 0.9983
# Epoch 75: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.0202 - val_accuracy: 0.9926
# Epoch 76/150
# 332/335 [============================>.] - ETA: 0s - loss: 0.0036 - accuracy: 0.9989
# Epoch 76: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.0241 - val_accuracy: 0.9937
# Epoch 77/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9983
# Epoch 77: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.0261 - val_accuracy: 0.9926
# Epoch 78/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9979
# Epoch 78: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 16ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0253 - val_accuracy: 0.9926
# Epoch 79/150
# 333/335 [============================>.] - ETA: 0s - loss: 0.0095 - accuracy: 0.9966
# Epoch 79: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0094 - accuracy: 0.9966 - val_loss: 0.0313 - val_accuracy: 0.9905
# Epoch 80/150
# 332/335 [============================>.] - ETA: 0s - loss: 0.0103 - accuracy: 0.9964
# Epoch 80: val_accuracy did not improve from 0.99366
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0385 - val_accuracy: 0.9873
# -----------------EVALUATION----------------
# 41/41 [==============================] - 1s 22ms/step - loss: 0.0356 - accuracy: 0.9908
# LOSS:  0.03563851863145828
# ACCURACY:  0.9907904863357544

# %%
# Make predictions on test data
y_pred = model_cnn.predict(processed_X_test)
# Convert predictions to labels
y_pred = tf.argmax(y_pred, axis=1).numpy()

# Calculate precision, recall, and f1-score
precision = precision_score(tf.argmax(y_test, axis=1).numpy(), y_pred, average='weighted')
recall = recall_score(tf.argmax(y_test, axis=1).numpy(), y_pred, average='weighted')
f1 = f1_score(tf.argmax(y_test, axis=1).numpy(), y_pred, average='weighted')

print('PRECISION: ', precision)
print('RECALL: ', recall)
print('F1-SCORE: ', f1)
# Out:
# 41/41 [==============================] - 0s 3ms/step
# PRECISION:  0.9918026286444894
# RECALL:  0.9907904834996163
# F1-SCORE:  0.9909883672332211

# %%
# Get the accuracy and validation accuracy from the history object
acc = history_cnn.history['accuracy']
val_acc = history_cnn.history['val_accuracy']

# Get the loss and validation loss from the history object
loss = history_cnn.history['loss']
val_loss = history_cnn.history['val_loss']

# %%
# Plot the accuracy
plt.figure(figsize=(8, 4))
plt.plot(range(len(acc)), acc, label='Train Accuracy')
plt.plot(range(len(val_acc)), val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('accuracy_plot.jpg')
plt.show()

# %%
# Plot the loss
plt.figure(figsize=(8, 4))
plt.plot(range(len(loss)), loss, label='Train Loss')
plt.plot(range(len(val_loss)), val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('loss_plot.jpg')
plt.show()

# %%
# Save the model as a SavedModel
tfjs.converters.save_keras_model(model_cnn, tfjs_model_dir)
print('tfjs model saved at ',tfjs_model_dir)
# Out:
# tfjs model saved at  model
# /Users/oabas/miniconda3/lib/python3.9/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
