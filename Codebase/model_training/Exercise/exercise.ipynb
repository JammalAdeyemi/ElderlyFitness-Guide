# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the data
df1 = pd.read_csv('../../../Data/exercise/exercises.csv')
df2 = pd.read_csv('../../../Data/exercise/exercises1.csv')
df3 = pd.read_csv('../../../Data/exercise/exercises2.csv')
df4 = pd.read_csv('../../../Data/exercise/exercises3.csv')
df5 = pd.read_csv('../../../Data/exercise/exercises4.csv')

# %%
# Concatenate the data into one DataFrame
df = pd.concat([df1, df2, df3, df4, df5],  ignore_index=True)
df.head()
# Out:
#     exercise    x_NOSE    y_NOSE    z_NOSE  x_LEFT_EYE_INNER  \
# 0  arm_raise  0.895049  0.420895 -0.581199          0.892313
# 1  arm_raise  0.894872  0.420184 -0.553994          0.891818
# 2  arm_raise  0.894685  0.420571 -0.570119          0.891803
# 3  arm_raise  0.893819  0.420329 -0.588238          0.891507
# 4  arm_raise  0.891471  0.421765 -0.596245          0.889994
#
#    y_LEFT_EYE_INNER  z_LEFT_EYE_INNER  x_LEFT_EYE  y_LEFT_EYE  z_LEFT_EYE  \
# 0          0.408700         -0.556801    0.894141    0.408855   -0.557200
# 1          0.407885         -0.529718    0.893629    0.408056   -0.530110
# 2          0.408022         -0.545784    0.893705    0.408279   -0.546184
# 3          0.407759         -0.563392    0.893403    0.407826   -0.563779
# 4          0.408466         -0.572832    0.891864    0.408193   -0.573226
#
#    ...  z_LEFT_HEEL  x_RIGHT_HEEL  y_RIGHT_HEEL  z_RIGHT_HEEL  \
# 0  ...     0.505186      0.769068      0.923458      0.053107
# ...

# %%
# Check the info of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227255 entries, 0 to 53127
# Data columns (total 100 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   exercise            227255 non-null  object
#  1   x_NOSE              227255 non-null  float64
#  2   y_NOSE              227255 non-null  float64
#  3   z_NOSE              227255 non-null  float64
#  4   x_LEFT_EYE_INNER    227255 non-null  float64
#  5   y_LEFT_EYE_INNER    227255 non-null  float64
#  6   z_LEFT_EYE_INNER    227255 non-null  float64
#  7   x_LEFT_EYE          227255 non-null  float64
#  8   y_LEFT_EYE          227255 non-null  float64
#  9   z_LEFT_EYE          227255 non-null  float64
#  10  x_LEFT_EYE_OUTER    227255 non-null  float64
#  11  y_LEFT_EYE_OUTER    227255 non-null  float64
#  12  z_LEFT_EYE_OUTER    227255 non-null  float64
#  13  x_RIGHT_EYE_INNER   227255 non-null  float64
#  14  y_RIGHT_EYE_INNER   227255 non-null  float64
# ...

# %%
df.shape
# Out:
# (227255, 100)

# %%
# Check the distribution of the labels
df.describe()
# Out:
#               x_NOSE         y_NOSE         z_NOSE  x_LEFT_EYE_INNER  \
# count  227255.000000  227255.000000  227255.000000     227255.000000
# mean        0.499036       0.568038      -0.282265          0.502629
# std         0.205060       0.205116       0.221931          0.205119
# min        -0.213218       0.113652      -1.856620         -0.234922
# 25%         0.333810       0.403680      -0.400965          0.336711
# 50%         0.506194       0.446859      -0.276257          0.509369
# 75%         0.674018       0.779392      -0.172546          0.677375
# max         1.001269       1.143714       1.058048          1.002741
#
#        y_LEFT_EYE_INNER  z_LEFT_EYE_INNER     x_LEFT_EYE     y_LEFT_EYE  \
# count     227255.000000     227255.000000  227255.000000  227255.000000
# mean           0.560364         -0.271111       0.505372       0.560215
# std            0.207525          0.221932       0.205100       0.207081
# ...

# %%
df['exercise'].value_counts()
# Out:
# arm_raise         39947
# squat             34784
# curl              29438
# overhead_press    27833
# superman          22137
# fly               19010
# bird_dog          18568
# pushup            18344
# bicycle_crunch     8735
# leg_raise          8459
# Name: exercise, dtype: int64

# %%
df.isnull().sum()
# Out:
# exercise              0
# x_NOSE                0
# y_NOSE                0
# z_NOSE                0
# x_LEFT_EYE_INNER      0
#                      ..
# y_LEFT_FOOT_INDEX     0
# z_LEFT_FOOT_INDEX     0
# x_RIGHT_FOOT_INDEX    0
# y_RIGHT_FOOT_INDEX    0
# z_RIGHT_FOOT_INDEX    0
# Length: 100, dtype: int64

# %% [markdown]
# ## Model Training

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
